# %%
from  selenium import webdriver
import time
import pandas as pd
import operator

# %%
chrome_path = r"C:\Users\saxou\Desktop\PYTHON HACK\Web Scrapping\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(chrome_path)

# %%
driver.get("https://www.mediamarkt.nl/nl/category/_smartphones-483222.html?searchParams=&sort=&view=PRODUCTLIST&page=")
#time.sleep(10)

# %%
file2 = open('models.txt','r')
model_names = set([x.replace('\n','') for x in file2.readlines()])
brands_txt = set(['google','huawei','nokia','samsung','ulefone','meizu','apple','wileyfox','wiko','motorola','xiaomi','cat','crosscall','doro','alcatel','asus','fairphone','land-rover','ruggear','gigaset','honor','lg','oneplus','oppo','ruggear','sony','renewd'])
colors_txt = set(['space grey','prism','green','gold','purple','ceramic black','prism white','space gray','goud','rose gold','midnight green','keramisch','silver','wit','zilver','rose gold','grijs','rood','black','yellow','white','red','magenta','cyan','zwart','groen','blauw','paars','rosé goud','geel','oranje','brons','bruin','roze'])

# %%
driver.find_element_by_class_name('cookie-info-accept-button').click()

# %%
brands=[]
models=[]
colors=[]
prices=[]
storages=[]
hrefs=[]
i=0
while i<20:
    try:
        products = driver.find_elements_by_class_name("product-wrapper")
        title_2 = []

        for elem in products:
            title_2.append(elem.find_element_by_css_selector("h2"))
            
            name = elem.find_element_by_css_selector("h2").text.lower()
            print(name)
            try:
                tmp = {}
                for clr in colors_txt:
                    #print(clr)
                    if clr in name:
                        tmp[clr] = len(clr)
                colors.append(max(tmp.items(), key=operator.itemgetter(1))[0])
                #print(max(tmp.items(), key=operator.itemgetter(1))[0])
            except:
                colors.append("-")

            try:
                tmp = {}
                for mdl in model_names:
                    #print(mdl)
                    if mdl.lower() in name:
                        tmp[mdl] = len(mdl)
                models.append(max(tmp.items(), key=operator.itemgetter(1))[0])
                print(max(tmp.items(), key=operator.itemgetter(1))[0])
            except:
                models.append("-")

        for elem in title_2:
            elem = elem.text
            elem = elem.split()
            #print(elem)
        
        for elem in title_2:
            elem = elem.text
            #print(elem)
            elem_splt = elem.split()
            brands.append(elem_splt[0])
        
        for elem in products:
            a=elem.find_elements_by_class_name("product-details")
            for i,b in enumerate(a):
                arr = b.text.split()
                #print(arr)                
                if "Geheugencapaciteit:" in arr:
                    for el in arr:
                        if "Geheugencapaciteit:" in el:
                            #print(arr[arr.index(el)+1])
                            storages.append(arr[arr.index(el)+1]+arr[arr.index(el)+2])
                else:
                    arr=title_2[i].text.split()
                    for el in arr:
                        if "GB" in el:
                            storages.append(arr[arr.index(el)-1]+arr[arr.index(el)])

        products = driver.find_element_by_class_name("products-list")
        ps = products.find_elements_by_class_name("small")

        spans=[]

        for p in ps:
            spans.append(p.find_elements_by_css_selector("span"))

        for p in ps:
            span = p.find_elements_by_css_selector("span")
            price = []
            for spn in span:
                price.append(spn.text)
            price = ''.join(price)
            prices.append(price)
            
        contents = products.find_elements_by_class_name("content")
        h2s=[]
        for el in contents:
            h2s.append(el.find_elements_by_css_selector("h2"))

        for h2 in h2s:
            for x in h2:
                a = x.find_element_by_css_selector("a")
                href = a.get_attribute("href")
                hrefs.append(href)
        
        
        driver.find_element_by_class_name("pagination-next").click()
# nokia 8.1 - 64 gb dual-sim grijs
# 8.1
# alcatel 3 (2019) - 64 gb dual-sim blauw/paars
# 20
# samsung galaxy a6+ (2018) - 32 gb dual-sim zwart
# 20
# nokia 8.1 - 64 gb dual-sim blauw
# 8.1
# alcatel 3 (2019) - 32 gb dual-sim zwart/blauw
# 20
# nokia 7.2 - 128 gb dual-sim grijs
# 7.2
# samsung galaxy a5 (2017) - 32 gb goud
# 20
# apple iphone 6s plus - 32 gb roségoud
# Iphone 6s Plus
# apple iphone xs - 256 gb grijs
# Iphone Xs
# apple iphone xs - 256 gb goud
# Iphone Xs
# apple iphone xs - 256 gb zilver
# Iphone Xs
# apple iphone xs - 512 gb zilver
# Iphone Xs
# apple iphone xs - 512 gb grijs
# Iphone Xs
# alcatel pixi 4 (4) (3g) - 4 gb dual-sim wit
# apple iphone xs - 512 gb goud
# Iphone Xs
# huawei p20 lite - 64 gb dual-sim blauw
# P20 Lite
# apple iphone xs max - 64 gb goud
# Iphone Xs Max
# apple iphone xs max - 64 gb zilver
# Iphone Xs Max
# apple iphone xs max - 256 gb zilver
# Iphone Xs Max
# apple iphone xs max - 256 gb grijs
# Iphone Xs Max
# apple iphone xs max - 512 gb grijs
# Iphone Xs Max
# htc 10 32gb zilver
# 10
# apple iphone xs max - 256 gb goud
# Iphone Xs Max
# apple iphone xs max - 512 gb goud
# Iphone Xs Max
# apple iphone 6s - 32 gb goud
# Iphone 6s
# apple iphone xs max - 512 gb zilver
# Iphone Xs Max
# huawei p smart - 32 gb dual-sim blauw
# P Smart
# apple iphone 11 pro - 64 gb goud
# Iphone 11 Pro
# motorola moto e5 plus - 32 gb dual-sim grijs
# motorola moto e5 plus - 32 gb dual-sim goud
# wiko sunny3 - 8 gb dual-sim rood
# samsung galaxy s10 - 512 gb dual-sim groen
# Galaxy S10
# blackberry motion - 32 gb zwart
# samsung galaxy s10 - 512 gb dual-sim wit
# Galaxy S10
# alcatel a3 - 16 gb wit
# apple iphone 7 - 256 gb gitzwart
# Iphone 7
# apple iphone 7 - 128 gb goud
# Iphone 7
# sony xperia l3 - 32 gb dual-sim zwart
# Xperia L3
# apple iphone 7 - 256 gb zilver
# Iphone 7
# sony xperia 10 plus - 64 gb dual-sim zilver
# Xperia 10 Plus
# honor 7x - 64 gb dual-sim blauw
# apple iphone 7 - 128 gb zilver
# Iphone 7
# samsung galaxy note10 plus - 256 gb dual-sim aura zwart
# 10
# huawei mate 20 pro - 128 gb dual-sim twilight
# Mate 20 Pro
# samsung galaxy note10 - 256 gb dual-sim aura zwart
# 10
# apple iphone 7 plus - 128 gb zwart
# Iphone 7 Plus
# huawei mate 20 pro - 128 gb dual-sim zwart
# Mate 20 Pro
# apple iphone 11 - 256 gb wit
# Iphone 11
# honor 9 lite - 32 gb dual-sim zilver
# honor 9 lite - 32 gb dual-sim zwart
# sony xperia l3 - 32 gb dual-sim zilver
# Xperia L3
# archos core 57s - 16 gb dual-sim blauw
# apple iphone 11 pro max - 512 gb middernachtgroen (groen)
# Iphone 11 Pro Max
# apple iphone 11 pro - 64 gb zilver
# Iphone 11 Pro
# oppo ax7 - 64 gb dual-sim blauw
# cat s31 - 16 gb dual-sim zwart
# S31
# nokia 3.1 plus - 32 gb dual-sim blauw
# 1 Plus
# samsung galaxy a8 - 32 gb dual-sim goud
# motorola moto g7 plus - 64 gb dual-sim blauw
# Moto G7 Plus
# samsung galaxy a8 - 32 gb dual-sim zwart
# apple iphone 7 plus - 128 gb goud
# Iphone 7 Plus
# apple iphone 7 plus - 32 gb zilver
# Iphone 7 Plus
# blackberry key2 qwerty - 64 gb zilver
# sony xperia xz3 - 64 gb dual-sim zilver
# Xperia Xz3
# motorola moto g6 play - 32 gb dual-sim blauw
# Moto G6
# lg k11 - 16 gb zwart
# apple iphone 7 plus - 128 gb roségoud
# Iphone 7 Plus
# apple iphone 11 - 256 gb groen
# Iphone 11
# archos core 55s ultra - 32 gb dual-sim blauw
# blackberry keyone - 64 gb zwart
# nokia 1 plus - 8 gb dual-sim blauw
# 1 Plus
# samsung galaxy s10 - 128 gb dual-sim groen
# Galaxy S10
# oppo find x - 256 gb dual-sim blauw
# Find X
# oppo find x - 256 gb dual-sim rood
# Find X
# lg q7 - 32 gb bts edition zwart
# archos core 62s - 16 gb dual-sim zwart
# wiko harry - 16 gb dual-sim grijs
# motorola moto g7 - 64 gb dual-sim zwart
# Moto G7
# samsung galaxy a80 - 128 gb dual-sim zilver
# Galaxy A80
# apple iphone 6s - 32 gb zilver
# Iphone 6s
# motorola moto g5s - 32 gb goud
# crosscall odyssey+ - 4 gb groen
# huawei y5 (2019) - 16 gb dual-sim bruin
# Y5 (2019)

# %%
all_df = pd.DataFrame(columns=['Brand','Price','Storage',"Link","Color","Model"])
all_df['Model'] = models
all_df['Brand'] = brands
all_df['Price'] = prices
all_df['Color'] = colors
all_df['Storage'] = storages
all_df['Link'] = hrefs
all_df.to_excel('mediamarkt.xls')
all_df
# Out:
#          Brand   Price Storage  \
# 0      SAMSUNG   399,-    64GB
# 1      SAMSUNG   295,-   128GB
# 2      SAMSUNG   580,-   128GB
# 3        APPLE   705,-    64GB
# 4      SAMSUNG   399,-    64GB
# ..         ...     ...     ...
# 331    SAMSUNG   565,-   128GB
# 332      APPLE   355,-    32GB
# 333   MOTOROLA   137,-    32GB
# 334  CROSSCALL   149,-     4GB
# 335     HUAWEI  104,99    16GB
#
#                                                   Link   Color        Model
# 0    https://www.mediamarkt.nl/nl/product/_samsung-...   zwart    Galaxy S8
# 1    https://www.mediamarkt.nl/nl/product/_samsung-...   zwart   Galaxy A50
# 2    https://www.mediamarkt.nl/nl/product/_samsung-...   zwart  Galaxy S10e
# 3    https://www.mediamarkt.nl/nl/product/_apple-ip...   zwart    Iphone Xr
# 4    https://www.mediamarkt.nl/nl/product/_samsung-...  zilver    Galaxy S8
# ..                                                 ...     ...          ...
# 331  https://www.mediamarkt.nl/nl/product/_samsung-...  zilver   Galaxy A80
# 332  https://www.mediamarkt.nl/nl/product/_apple-ip...  zilver    Iphone 6s
# 333  https://www.mediamarkt.nl/nl/product/_motorola...    goud            -
# 334  https://www.mediamarkt.nl/nl/product/_crosscal...   groen            -
# 335  https://www.mediamarkt.nl/nl/product/_huawei-y...   bruin    Y5 (2019)
#
# [336 rows x 6 columns]
